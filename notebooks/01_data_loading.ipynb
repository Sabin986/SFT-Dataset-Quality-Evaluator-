# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("C:\\Users\\Legion\\Downloads\\SFT_Contextual_10000_updated.xlsx")
print("Dataset loaded successfully!")
df
# Out:
# Dataset loaded successfully!
#                                         id        domain  \
# 0     8bcd7516-264f-4d52-8d24-223a4519d71b       finance
# 1     02b6b474-7e0a-4d26-b58d-26caeda87200     marketing
# 2     13741ac3-de4c-4f18-ad04-0f9aca9e8434  productivity
# 3     01de4e88-64aa-45f3-befb-c077e83e5418        sports
# 4     b04b6a43-d366-4b48-bbb7-9f2e075205e2           law
# ...                                    ...           ...
# 9995  28b08e2c-1491-4bcb-9081-f2d9c3edd813    healthcare
# 9996  c438da14-6945-46d4-b5e1-109cbdf6365d     education
# 9997  93e27108-959a-40cb-abec-0a03b0ea07fa        sports
# 9998  0cc166fa-7b81-407c-bbf5-57df5fec39a7           law
# 9999  078765ed-2d01-4932-9c3a-f0e24f300db5     marketing
#
#                                             instruction  \
# 0     Calculate compound interest from the details b...
# 1     Suggest a campaign slogan from this product de...
# 2         Create a daily schedule using this task list.
# ...

# %%
#datasize visualization
print("Dataset Shape:", df.shape)

print("Total Rows:", df.shape[0])
print("Total Columns:", df.shape[1])
# Out:
# Dataset Shape: (10000, 6)
# Total Rows: 10000
# Total Columns: 6

# %%
#top 5 rows
df.head()
# Out:
#                                      id        domain  \
# 0  8bcd7516-264f-4d52-8d24-223a4519d71b       finance
# 1  02b6b474-7e0a-4d26-b58d-26caeda87200     marketing
# 2  13741ac3-de4c-4f18-ad04-0f9aca9e8434  productivity
# 3  01de4e88-64aa-45f3-befb-c077e83e5418        sports
# 4  b04b6a43-d366-4b48-bbb7-9f2e075205e2           law
#
#                                          instruction  \
# 0  Calculate compound interest from the details b...
# 1  Suggest a campaign slogan from this product de...
# 2      Create a daily schedule using this task list.
# 3                         Summarize the game report.
# 4                    Summarize this legal paragraph.
#
#                                                input  \
# 0         Principal: $1,000, Rate: 5%, Time: 3 years
# 1  A smartwatch that monitors your health in real...
# 2  Write report, team meeting, client call, gym, ...
# 3  Team A scored 3 goals in the second half to wi...
# ...

# %%
#dataset columns visualization
print("Dataset Columns:")

for column in df.columns:
    print("-", column)
# Out:
# Dataset Columns:
# - id
# - domain
# - instruction
# - input
# - output
# - source

# %%
#checking data types of each column
print(df.dtypes)
# Out:
# id             object
# domain         object
# instruction    object
# input          object
# output         object
# source         object
# dtype: object

# %%
missing_values = df.isnull().sum()

print("Missing Values in Each Column:")
print(missing_values)
# Out:
# Missing Values in Each Column:
# id             0
# domain         0
# instruction    0
# input          0
# output         0
# source         0
# dtype: int64

# %%
duplicate_rows = df.duplicated().sum()

print("Total Duplicate Rows:", duplicate_rows)
# Out:
# Total Duplicate Rows: 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           10000 non-null  object
#  1   domain       10000 non-null  object
#  2   instruction  10000 non-null  object
#  3   input        10000 non-null  object
#  4   output       10000 non-null  object
#  5   source       10000 non-null  object
# dtypes: object(6)
# memory usage: 468.9+ KB

# %%
print("SFT DATASET INITIAL SUMMARY")

print(f"Total Rows: {df.shape[0]}")
print(f"Total Columns: {df.shape[1]}")

print("\nColumn Names:")
print(df.columns.tolist())

print("\nTotal Missing Values:")
print(df.isnull().sum().sum())

print("\nTotal Duplicate Rows:")
print(df.duplicated().sum())
# Out:
# SFT DATASET INITIAL SUMMARY
# Total Rows: 10000
# Total Columns: 6
#
# Column Names:
# ['id', 'domain', 'instruction', 'input', 'output', 'source']
#
# Total Missing Values:
# 0
#
# Total Duplicate Rows:
# 0

# %%
# Save the original dataset in CSV format

output_path = "../data/raw/sft_dataset.csv"

df.to_csv(
    output_path,
    index=False
)

print("Original dataset saved as sft_dataset.csv")
# Out:
# Original dataset saved as sft_dataset.csv
